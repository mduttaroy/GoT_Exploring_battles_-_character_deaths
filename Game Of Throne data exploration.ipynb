# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)

import matplotlib.pyplot as plt

import seaborn as sns

# %%
battle = pd.read_csv('battles.csv')

# %%
battle.shape
# Out:
# (38, 25)

# %%
battle.sample(5)
# Out:
#                                                  name  year  battle_number  \
# 14                                  Battle of Oxcross   299             15
# 25                                    The Red Wedding   299             26
# 27                             Battle of Castle Black   300             28
# 10                         Battle of Torrhen's Square   299             11
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...   300             33
#
#                attacker_king             defender_king attacker_1 attacker_2  \
# 14                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 25  Joffrey/Tommen Baratheon                Robb Stark       Frey     Bolton
# 27         Stannis Baratheon              Mance Rayder  Free folk     Thenns
# 10                Robb Stark       Balon/Euron Greyjoy      Stark        NaN
# 32       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon    Greyjoy        NaN
#
#    attacker_3 attacker_4     defender_1 defender_2  defender_3  defender_4  \
# 14        NaN        NaN      Lannister        NaN         NaN         NaN
# 25        NaN        NaN          Stark        NaN         NaN         NaN
# 27     Giants        NaN  Night's Watch  Baratheon         NaN         NaN
# 10        NaN        NaN        Greyjoy        NaN         NaN         NaN
# 32        NaN        NaN         Tyrell        NaN         NaN         NaN
#
#    attacker_outcome     battle_type  major_death  major_capture  \
# 14              win          ambush          1.0            1.0
# 25              win          ambush          1.0            1.0
# 27             loss           siege          1.0            1.0
# 10              win  pitched battle          0.0            0.0
# 32              win          razing          0.0            0.0
#
#     attacker_size  defender_size  \
# 14         6000.0        10000.0
# 25         3500.0         3500.0
# 27       100000.0         1240.0
# 10          244.0          900.0
# 32            NaN            NaN
#
#                                    attacker_commander  \
# 14                          Robb Stark, Brynden Tully
# 25           Walder Frey, Roose Bolton, Walder Rivers
# 27  Mance Rayder, Tormund Giantsbane, Harma Dogshe...
# 10                         Rodrik Cassel, Cley Cerwyn
# 32                   Euron Greyjoy, Victarion Greyjoy
#
#                                    defender_commander  summer  \
# 14  Stafford Lannister, Roland Crakehall, Antario ...     1.0
# 25                                         Robb Stark     1.0
# 27  Stannis Baratheon, Jon Snow, Donal Noye, Cotte...     0.0
# 10                                    Dagmer Cleftjaw     1.0
# 32                                                NaN     0.0
#
#                                 location           region  \
# 14                               Oxcross  The Westerlands
# 25                             The Twins   The Riverlands
# 27                          Castle Black  Beyond the Wall
# 10                      Torrhen's Square        The North
# 32  Ryamsport, Vinetown, Starfish Harbor        The Reach
#
#                                                  note
# 14                                                NaN
# 25  This observation refers to the battle against ...
# 27                                                NaN
# 10  Greyjoy's troop number comes from the 264 esti...
# 32                                                NaN

# %%
battle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
# name                  38 non-null object
# year                  38 non-null int64
# battle_number         38 non-null int64
# attacker_king         36 non-null object
# defender_king         35 non-null object
# attacker_1            38 non-null object
# attacker_2            10 non-null object
# attacker_3            3 non-null object
# attacker_4            2 non-null object
# defender_1            37 non-null object
# defender_2            2 non-null object
# defender_3            0 non-null float64
# defender_4            0 non-null float64
# attacker_outcome      37 non-null object
# battle_type           37 non-null object
# major_death           37 non-null float64
# major_capture         37 non-null float64
# attacker_size         24 non-null float64
# defender_size         19 non-null float64
# attacker_commander    37 non-null object
# defender_commander    28 non-null object
# summer                37 non-null float64
# location              37 non-null object
# region                38 non-null object
# note                  5 non-null object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 7.5+ KB
